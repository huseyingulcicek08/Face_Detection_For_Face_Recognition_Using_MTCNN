# %%
# !pip install deepface
# !pip install dlib
# !pip install mtcnn
from deepface import DeepFace
import matplotlib.pyplot as plt
import time

# %%
img_path="PycharmProjects/UsingMTCNN/friends.jpg"
detectors = ['opencv','ssd','dlib','mtcnn']
for detector in detectors:
    print(detector)
    tic=time.time()
    img = DeepFace.detectFace(img_path=img_path,detector_backend = detector)
    toc=time.time()
    plt.imshow(img)
    plt.show()
    
    print(detector, " backend",toc-tic, " seconds")
    print("****************************")
# Out:
# opencv
# opencv  backend 1.3579986095428467  seconds
# ****************************
# ssd
# ssd  backend 1.6119983196258545  seconds
# ****************************
# dlib
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-f508aaaf61f6> in <module>
#       4     print(detector)
#       5     tic=time.time()
# ----> 6     img = DeepFace.detectFace(img_path=img_path,detector_backend = detector)
#       7     toc=time.time()
#       8     plt.imshow(img)
#
# C:\Anaconda3\lib\site-packages\deepface\DeepFace.py in detectFace(img_path, detector_backend)
#     748 	"""
#     749
# --> 750         functions.initialize_detector(detector_backend = detector_backend)
#     751
#     752         img = functions.preprocess_face(img = img_path, detector_backend = detector_backend)[0] #preprocess_face returns (1, 224, 224, 3)
#
# C:\Anaconda3\lib\site-packages\deepface\commons\functions.py in initialize_detector(detector_backend)
#     110
#     111         elif detector_backend == 'dlib':
# --> 112                 import dlib #this is not a must library within deepface. that's why, I didn't put this import to a global level. version: 19.20.0
#     113
#     114                 global sp
#
# ModuleNotFoundError: No module named 'dlib'
